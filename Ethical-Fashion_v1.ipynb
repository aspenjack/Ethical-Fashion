# %%
#Authors: Velvet Robinson, Samin Nikkhoo, Aspen Jack, Christina Zermeno, Arpita Sharma
#Project: Ethical Fashion, creating data visualizations using Fashion Revolution
#Link: https://www.fashionrevolution.org/ 
#Data downloaded from: https://wikirate.org/Fashion_Revolution+Fashion_Transparency_Index_2021
# Data we are using includes the company list, headquarters,and metrics for Decarbonization and Deforestation, 
#Towards Paying Living Wages, Overconsumption Waste Circulatory Answer, Sustainable Sourcing.

# %%
#importing the dependencies we will be using here
import pandas as pd
import csv 
from sqlalchemy import create_engine
import os
import numpy as np

# %%
#Files we will be using are here: 

company_headquarters = "Resources/Company_Headquarters.csv"
decarbonization_score = "Resources/Metrics/Decarbonisation_Deforestation_and_Regeneration_Scores.csv"
overconsumption_score = "Resources/Metrics/Overconsumption_Waste_Circularity_Scores.csv"
sustainable_materials_score = "Resources/Metrics/Sustainable_Sourcing_Materials_Scores.csv"
living_wage_score = "Resources/Metrics/Towards_Paying_Living_Wages_Scores.csv"

#now reading them in as pd dataframes
company_df = pd.read_csv(company_headquarters, header=4)
decarbonization_df = pd.read_csv(decarbonization_score, header=4)
overconsumption_df = pd.read_csv(overconsumption_score,header=4)
sustainable_materials_df = pd.read_csv(sustainable_materials_score,header=4)
living_wage_df = pd.read_csv(living_wage_score,header=4)

# %%
#checking all the tables are showing up correctly
#company_df
#decarbonization_df
#overconsumption_df
#sustainable_materials_df
#living_wage_df

# %%
#adding metric files together
concatenated_df = pd.concat([decarbonization_df, overconsumption_df, sustainable_materials_df, living_wage_df], ignore_index=True)

# %%
#checking merged dataset
concatenated_df
#contains 1202 rows, which combines all rows from csv files
# Out:
#                                             Answer Page  \
# 0     https://wikirate.org/Fashion_Revolution+Decarb...
# 1     https://wikirate.org/Fashion_Revolution+Decarb...
# 2     https://wikirate.org/Fashion_Revolution+Decarb...
# 3     https://wikirate.org/Fashion_Revolution+Decarb...
# 4     https://wikirate.org/Fashion_Revolution+Decarb...
# ...                                                 ...
# 1197  https://wikirate.org/Fashion_Revolution+Toward...
# 1198  https://wikirate.org/Fashion_Revolution+Toward...
# 1199  https://wikirate.org/Fashion_Revolution+Toward...
# 1200  https://wikirate.org/Fashion_Revolution+Toward...
# 1201  https://wikirate.org/Fashion_Revolution+Toward...
#
#                                                  Metric  \
# 0     Fashion Revolution+Decarbonisation, Deforestat...
# 1     Fashion Revolution+Decarbonisation, Deforestat...
# 2     Fashion Revolution+Decarbonisation, Deforestat...
# 3     Fashion Revolution+Decarbonisation, Deforestat...
# 4     Fashion Revolution+Decarbonisation, Deforestat...
# ...                                                 ...
# 1197  Fashion Revolution+Towards Paying Living Wages...
# 1198  Fashion Revolution+Towards Paying Living Wages...
# 1199  Fashion Revolution+Towards Paying Living Wages...
# 1200  Fashion Revolution+Towards Paying Living Wages...
# 1201  Fashion Revolution+Towards Paying Living Wages...
#
#                                Company  Year      Value  Source Page
# 0                                Gucci  2021  10.000000          NaN
# 1                        Saint Laurent  2021  10.000000          NaN
# 2                       Bottega Veneta  2021  10.000000          NaN
# 3                           Balenciaga  2021  10.000000          NaN
# 4                                  H&M  2021   8.571429          NaN
# ...                                ...   ...        ...          ...
# 1197                  T.T. Blues Jeans  2021   0.000000          NaN
# 1198                  Verochi SA de CV  2021   0.000000          NaN
# 1199           Yale de Mexico SA de CV  2021   0.000000          NaN
# 1200         Ilusion (Diltex SA de CV)  2021   0.000000          NaN
# 1201  Oggi (Junior de Mexico SA de CV)  2021   0.000000          NaN
#
# [1202 rows x 6 columns]

# %%
#Splitting metric to take out Fashion Revolution from text
concatenated_df[["Metric1","Metric2"]] = concatenated_df["Metric"].str.split('+',expand=True)
concatenated_df[["Metric3","Metric4"]] = concatenated_df["Metric2"].str.split('(',expand=True)

# %%
#Reviewing cleaned_df here:
concatenated_df

#Looks good, we will now drop metric and metric1, metric2, metrict4
# Out:
#                                             Answer Page  \
# 0     https://wikirate.org/Fashion_Revolution+Decarb...
# 1     https://wikirate.org/Fashion_Revolution+Decarb...
# 2     https://wikirate.org/Fashion_Revolution+Decarb...
# 3     https://wikirate.org/Fashion_Revolution+Decarb...
# 4     https://wikirate.org/Fashion_Revolution+Decarb...
# ...                                                 ...
# 1197  https://wikirate.org/Fashion_Revolution+Toward...
# 1198  https://wikirate.org/Fashion_Revolution+Toward...
# 1199  https://wikirate.org/Fashion_Revolution+Toward...
# 1200  https://wikirate.org/Fashion_Revolution+Toward...
# 1201  https://wikirate.org/Fashion_Revolution+Toward...
#
#                                                  Metric  \
# 0     Fashion Revolution+Decarbonisation, Deforestat...
# 1     Fashion Revolution+Decarbonisation, Deforestat...
# 2     Fashion Revolution+Decarbonisation, Deforestat...
# 3     Fashion Revolution+Decarbonisation, Deforestat...
# 4     Fashion Revolution+Decarbonisation, Deforestat...
# ...                                                 ...
# 1197  Fashion Revolution+Towards Paying Living Wages...
# 1198  Fashion Revolution+Towards Paying Living Wages...
# 1199  Fashion Revolution+Towards Paying Living Wages...
# 1200  Fashion Revolution+Towards Paying Living Wages...
# 1201  Fashion Revolution+Towards Paying Living Wages...
#
#                                Company  Year      Value  Source Page  \
# 0                                Gucci  2021  10.000000          NaN
# 1                        Saint Laurent  2021  10.000000          NaN
# 2                       Bottega Veneta  2021  10.000000          NaN
# 3                           Balenciaga  2021  10.000000          NaN
# 4                                  H&M  2021   8.571429          NaN
# ...                                ...   ...        ...          ...
# 1197                  T.T. Blues Jeans  2021   0.000000          NaN
# 1198                  Verochi SA de CV  2021   0.000000          NaN
# 1199           Yale de Mexico SA de CV  2021   0.000000          NaN
# 1200         Ilusion (Diltex SA de CV)  2021   0.000000          NaN
# 1201  Oggi (Junior de Mexico SA de CV)  2021   0.000000          NaN
#
#                  Metric1                                            Metric2  \
# 0     Fashion Revolution  Decarbonisation, Deforestation and Regeneratio...
# 1     Fashion Revolution  Decarbonisation, Deforestation and Regeneratio...
# 2     Fashion Revolution  Decarbonisation, Deforestation and Regeneratio...
# 3     Fashion Revolution  Decarbonisation, Deforestation and Regeneratio...
# 4     Fashion Revolution  Decarbonisation, Deforestation and Regeneratio...
# ...                  ...                                                ...
# 1197  Fashion Revolution           Towards Paying Living Wages Score (2021)
# 1198  Fashion Revolution           Towards Paying Living Wages Score (2021)
# 1199  Fashion Revolution           Towards Paying Living Wages Score (2021)
# 1200  Fashion Revolution           Towards Paying Living Wages Score (2021)
# 1201  Fashion Revolution           Towards Paying Living Wages Score (2021)
#
#                                                 Metric3 Metric4
# 0     Decarbonisation, Deforestation and Regeneratio...    None
# 1     Decarbonisation, Deforestation and Regeneratio...    None
# 2     Decarbonisation, Deforestation and Regeneratio...    None
# 3     Decarbonisation, Deforestation and Regeneratio...    None
# 4     Decarbonisation, Deforestation and Regeneratio...    None
# ...                                                 ...     ...
# 1197                 Towards Paying Living Wages Score    2021)
# 1198                 Towards Paying Living Wages Score    2021)
# 1199                 Towards Paying Living Wages Score    2021)
# 1200                 Towards Paying Living Wages Score    2021)
# 1201                 Towards Paying Living Wages Score    2021)
#
# [1202 rows x 10 columns]

# %%
#Dropping unnecessary variables here: 
dropped_df = concatenated_df.drop(columns =["Answer Page","Source Page", "Metric","Metric1","Metric2","Metric4"])
dropped_df
# Out:
#                                Company  Year      Value  \
# 0                                Gucci  2021  10.000000
# 1                        Saint Laurent  2021  10.000000
# 2                       Bottega Veneta  2021  10.000000
# 3                           Balenciaga  2021  10.000000
# 4                                  H&M  2021   8.571429
# ...                                ...   ...        ...
# 1197                  T.T. Blues Jeans  2021   0.000000
# 1198                  Verochi SA de CV  2021   0.000000
# 1199           Yale de Mexico SA de CV  2021   0.000000
# 1200         Ilusion (Diltex SA de CV)  2021   0.000000
# 1201  Oggi (Junior de Mexico SA de CV)  2021   0.000000
#
#                                                 Metric3
# 0     Decarbonisation, Deforestation and Regeneratio...
# 1     Decarbonisation, Deforestation and Regeneratio...
# 2     Decarbonisation, Deforestation and Regeneratio...
# 3     Decarbonisation, Deforestation and Regeneratio...
# 4     Decarbonisation, Deforestation and Regeneratio...
# ...                                                 ...
# 1197                 Towards Paying Living Wages Score
# 1198                 Towards Paying Living Wages Score
# 1199                 Towards Paying Living Wages Score
# 1200                 Towards Paying Living Wages Score
# 1201                 Towards Paying Living Wages Score
#
# [1202 rows x 4 columns]

# %%
#Renaming Metric3 to Metric
cleaned_df = dropped_df.rename(columns={"Metric3":"Metric"})
cleaned_df
company_df
# Out:
#                               Link                                    Name  \
# 0      https://wikirate.org/~60914                     Abercrombie & Fitch
# 1       https://wikirate.org/~7217                               Adidas AG
# 2    https://wikirate.org/~2612145                        Aeropostale Inc.
# 3    https://wikirate.org/~1830731  Airwair International Ltd (Dr Martens)
# 4      https://wikirate.org/~48256                               Aldi Nord
# ..                             ...                                     ...
# 244  https://wikirate.org/~5407364                                Wrangler
# 245  https://wikirate.org/~5785348                                 Youngor
# 246  https://wikirate.org/~2608717                              Zalando SE
# 247    https://wikirate.org/~18215                                    Zara
# 248  https://wikirate.org/~3096058                                  Zeeman
#
#           ID                    Headquarters
# 0      60914        New York (United States)
# 1       7217                         Germany
# 2    2612145        New York (United States)
# 3    1830731                  United Kingdom
# 4      48256                         Germany
# ..       ...                             ...
# 244  5407364  North Carolina (United States)
# 245  5785348                Zhejiang (China)
# 246  2608717                         Germany
# 247    18215                           Spain
# 248  3096058                     Netherlands
#
# [249 rows x 4 columns]

# %%
#Now checking if we need to clean headquarters
company_df["Headquarters"].unique()
#we do need to clean it, as there are some headquarters with state and country data, while others only have country data. 
#We will need to do this for United States, China, and Canada.
# Out:
# array(['New York (United States)', 'Germany', 'United Kingdom',
#        'Quebec (Canada)', 'Washington (United States)',
#        'Pennsylvania (United States)', 'Fujian (China)', 'Canada',
#        'Japan', 'Spain', 'Switzerland', 'California (United States)',
#        'Korea, Republic of', 'Guangdong (China)', 'India', 'Australia',
#        'Shanghai (China)', 'Italy', 'Nebraska (United States)',
#        'New Jersey (United States)', 'Belgium', 'Ontario, Canada',
#        'Michigan (United States)', 'France',
#        'North Carolina (United States)', 'Florida (United States)',
#        'Illinois (United States)', 'New Hampshire (United States)',
#        'Oregon (United States)', 'Massachusetts (United States)',
#        'Arkansas (United States)', 'Norway', 'Ohio (United States)',
#        'Hong Kong', 'Chile', 'Missouri (United States)', 'Sweden',
#        'South Africa', 'Texas (United States)', 'Netherlands',
#        'Jiangsu (China)', 'Denmark', 'Wisconsin (United States)',
#        'New Zealand', 'Beijing (China)', 'Maine (United States)',
#        'British Columbia (Canada)', 'Ireland', 'Poland',
#        'Kentucky (United States)', 'Finland', 'Minnesota (United States)',
#        'Maryland (United States)', 'Zhejiang (China)'], dtype=object)

# %%
#Creating separate country datasets here for the three countries
US_df = company_df[company_df["Headquarters"].str.contains("United States")]
CHINA_df = company_df[company_df["Headquarters"].str.contains("China")]
CAD_df = company_df[company_df["Headquarters"].str.contains("Canada")]


#Running checks to see if the datasets look okay
US_df
CHINA_df
CAD_df

#now creating a dataset for all the outher countries which currently have no issues
no_state_df = company_df[(~company_df["Headquarters"].str.contains("Canada"))& \
                         (~company_df["Headquarters"].str.contains("United States"))& \
                         (~company_df["Headquarters"].str.contains("China"))]
no_state_df
# Out:
#                               Link                                    Name  \
# 1       https://wikirate.org/~7217                               Adidas AG
# 3    https://wikirate.org/~1830731  Airwair International Ltd (Dr Martens)
# 4      https://wikirate.org/~48256                               Aldi Nord
# 5       https://wikirate.org/~5208                                Aldi Sud
# 12    https://wikirate.org/~170564                       Asics Corporation
# ..                             ...                                     ...
# 242   https://wikirate.org/~130172                         Warehouse Group
# 243    https://wikirate.org/~56864             Woolworths Holdings Limited
# 246  https://wikirate.org/~2608717                              Zalando SE
# 247    https://wikirate.org/~18215                                    Zara
# 248  https://wikirate.org/~3096058                                  Zeeman
#
#           ID    Headquarters
# 1       7217         Germany
# 3    1830731  United Kingdom
# 4      48256         Germany
# 5       5208         Germany
# 12    170564           Japan
# ..       ...             ...
# 242   130172     New Zealand
# 243    56864    South Africa
# 246  2608717         Germany
# 247    18215           Spain
# 248  3096058     Netherlands
#
# [142 rows x 4 columns]

# %%
#Creating State and Country columns in the no_state_df so that it's easier to add with the rest of the files later
no_state_df.insert(3,"State","")
column_to_set_null = "State"
no_state_df.loc[no_state_df["State"] == "", column_to_set_null] = np.nan
no_state_df["Country"] = no_state_df["Headquarters"]
no_state_df
# Out:
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\2434719041.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_state_df["Country"] = no_state_df["Headquarters"]
#                               Link                                    Name  \
# 1       https://wikirate.org/~7217                               Adidas AG
# 3    https://wikirate.org/~1830731  Airwair International Ltd (Dr Martens)
# 4      https://wikirate.org/~48256                               Aldi Nord
# 5       https://wikirate.org/~5208                                Aldi Sud
# 12    https://wikirate.org/~170564                       Asics Corporation
# ..                             ...                                     ...
# 242   https://wikirate.org/~130172                         Warehouse Group
# 243    https://wikirate.org/~56864             Woolworths Holdings Limited
# 246  https://wikirate.org/~2608717                              Zalando SE
# 247    https://wikirate.org/~18215                                    Zara
# 248  https://wikirate.org/~3096058                                  Zeeman
#
#           ID State    Headquarters         Country
# 1       7217   NaN         Germany         Germany
# 3    1830731   NaN  United Kingdom  United Kingdom
# 4      48256   NaN         Germany         Germany
# 5       5208   NaN         Germany         Germany
# 12    170564   NaN           Japan           Japan
# ..       ...   ...             ...             ...
# 242   130172   NaN     New Zealand     New Zealand
# 243    56864   NaN    South Africa    South Africa
# 246  2608717   NaN         Germany         Germany
# 247    18215   NaN           Spain           Spain
# 248  3096058   NaN     Netherlands     Netherlands
#
# [142 rows x 6 columns]

# %%
#Splitting headquarters so that city and country show up in separate columns

#United States
US_df[["State","Country"]] = US_df["Headquarters"].str.split('(',expand=True)
US_df['Country'] = US_df['Country'].str.rstrip(')')

#China
CHINA_df[["State","Country"]] = company_df["Headquarters"].str.split('(',expand=True)
CHINA_df['Country'] = CHINA_df['Country'].str.rstrip(')')

US_df
CHINA_df

# Remove the closing parentheses from the 'Country' column
#company_df
# Out:
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\273473213.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   US_df[["State","Country"]] = US_df["Headquarters"].str.split('(',expand=True)
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\273473213.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   US_df[["State","Country"]] = US_df["Headquarters"].str.split('(',expand=True)
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\273473213.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   US_df['Country'] = US_df['Country'].str.rstrip(')')
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\273473213.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CHINA_df[["State","Country"]] = company_df["Headquarters"].str.split('(',expand=True)
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\273473213.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CHINA_df[["State","Country"]] = company_df["Headquarters"].str.split('(',expand=True)
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\273473213.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CHINA_df['Country'] = CHINA_df['Country'].str.rstrip(')')
#                               Link                                     Name  \
# 10   https://wikirate.org/~5424735                     Anta Sports Products
# 19     https://wikirate.org/~49737             Belle International Holdings
# 27   https://wikirate.org/~5294189  Bosideng International Holdings Limited
# 103  https://wikirate.org/~2631045                              Heilan Home
# 136  https://wikirate.org/~1173485                                  Li-Ning
# 154  https://wikirate.org/~3624503                              Metersbonwe
# 245  https://wikirate.org/~5785348                                  Youngor
#
#           ID       Headquarters       State Country
# 10   5424735     Fujian (China)     Fujian    China
# 19     49737  Guangdong (China)  Guangdong    China
# 27   5294189   Shanghai (China)   Shanghai    China
# 103  2631045    Jiangsu (China)    Jiangsu    China
# 136  1173485    Beijing (China)    Beijing    China
# 154  3624503   Shanghai (China)   Shanghai    China
# 245  5785348   Zhejiang (China)   Zhejiang    China

# %%
#Canada
#CAD_df[["State","Country"]] = CAD_df["Headquarters"].str.split('(',expand=True)


# Split on commas and parentheses, and expand into separate columns
split_columns = CAD_df['Headquarters'].str.split(r'[,(]+', expand=True)


# Rename the columns to 'State' and 'Country'
split_columns.columns = ['State', 'Country']

# Assign the new columns to the original DataFrame
CAD_df[['State', 'Country']] = split_columns
CAD_df['Country'] = CAD_df['Country'].str.rstrip(')')

CAD_df
# Out:
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\4066584027.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CAD_df[['State', 'Country']] = split_columns
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\4066584027.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CAD_df[['State', 'Country']] = split_columns
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\4066584027.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CAD_df['Country'] = CAD_df['Country'].str.rstrip(')')
#                               Link                    Name       ID  \
# 6    https://wikirate.org/~5793646                    ALDO  5793646
# 11   https://wikirate.org/~5414341                 Aritzia  5414341
# 39   https://wikirate.org/~5408890            Canada Goose  5408890
# 98    https://wikirate.org/~116138  Gildan Activewear Inc.   116138
# 108  https://wikirate.org/~3098198    Hudson's Bay Company  3098198
# 119    https://wikirate.org/~44824               Joe Fresh    44824
# 143  https://wikirate.org/~1825510     lululemon athletica  1825510
#
#                   Headquarters              State  Country
# 6              Quebec (Canada)            Quebec    Canada
# 11                      Canada             Canada     None
# 39             Ontario, Canada            Ontario   Canada
# 98                      Canada             Canada     None
# 108            Ontario, Canada            Ontario   Canada
# 119            Ontario, Canada            Ontario   Canada
# 143  British Columbia (Canada)  British Columbia    Canada

# %%
column_to_set_null = "State"
CAD_df.loc[CAD_df["State"] == "Canada", column_to_set_null] = np.nan
CAD_df["Country"] ="Canada"

CAD_df
# Out:
# C:\Users\arpitas\AppData\Local\Temp\ipykernel_23868\2222763077.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CAD_df["Country"] ="Canada"
#                               Link                    Name       ID  \
# 6    https://wikirate.org/~5793646                    ALDO  5793646
# 11   https://wikirate.org/~5414341                 Aritzia  5414341
# 39   https://wikirate.org/~5408890            Canada Goose  5408890
# 98    https://wikirate.org/~116138  Gildan Activewear Inc.   116138
# 108  https://wikirate.org/~3098198    Hudson's Bay Company  3098198
# 119    https://wikirate.org/~44824               Joe Fresh    44824
# 143  https://wikirate.org/~1825510     lululemon athletica  1825510
#
#                   Headquarters              State Country
# 6              Quebec (Canada)            Quebec   Canada
# 11                      Canada                NaN  Canada
# 39             Ontario, Canada            Ontario  Canada
# 98                      Canada                NaN  Canada
# 108            Ontario, Canada            Ontario  Canada
# 119            Ontario, Canada            Ontario  Canada
# 143  British Columbia (Canada)  British Columbia   Canada

# %%
country_concat_df = pd.concat([US_df, CHINA_df, CAD_df, no_state_df], ignore_index=True)
country_concat_df
# Out:
#                               Link                         Name       ID  \
# 0      https://wikirate.org/~60914          Abercrombie & Fitch    60914
# 1    https://wikirate.org/~2612145             Aeropostale Inc.  2612145
# 2      https://wikirate.org/~11708             Amazon.com, Inc.    11708
# 3     https://wikirate.org/~862441    American Eagle Outfitters   862441
# 4    https://wikirate.org/~5455028                Anthropologie  5455028
# ..                             ...                          ...      ...
# 244   https://wikirate.org/~130172              Warehouse Group   130172
# 245    https://wikirate.org/~56864  Woolworths Holdings Limited    56864
# 246  https://wikirate.org/~2608717                   Zalando SE  2608717
# 247    https://wikirate.org/~18215                         Zara    18215
# 248  https://wikirate.org/~3096058                       Zeeman  3096058
#
#                      Headquarters          State        Country
# 0        New York (United States)      New York   United States
# 1        New York (United States)      New York   United States
# 2      Washington (United States)    Washington   United States
# 3    Pennsylvania (United States)  Pennsylvania   United States
# 4    Pennsylvania (United States)  Pennsylvania   United States
# ..                            ...            ...            ...
# 244                   New Zealand            NaN    New Zealand
# 245                  South Africa            NaN   South Africa
# 246                       Germany            NaN        Germany
# 247                         Spain            NaN          Spain
# 248                   Netherlands            NaN    Netherlands
#
# [249 rows x 6 columns]

# %%
#Drop variables for company dataset here:
company_drop_df = country_concat_df.drop(columns=["Link", "Headquarters"])
company_drop_df
# Out:
#                             Name       ID          State        Country
# 0            Abercrombie & Fitch    60914      New York   United States
# 1               Aeropostale Inc.  2612145      New York   United States
# 2               Amazon.com, Inc.    11708    Washington   United States
# 3      American Eagle Outfitters   862441  Pennsylvania   United States
# 4                  Anthropologie  5455028  Pennsylvania   United States
# ..                           ...      ...            ...            ...
# 244              Warehouse Group   130172            NaN    New Zealand
# 245  Woolworths Holdings Limited    56864            NaN   South Africa
# 246                   Zalando SE  2608717            NaN        Germany
# 247                         Zara    18215            NaN          Spain
# 248                       Zeeman  3096058            NaN    Netherlands
#
# [249 rows x 4 columns]

# %%
#rename name to Company
company_cleaned_df = company_drop_df.rename(columns={"Name":"Company"})

company_cleaned_df
# Out:
#                          Company       ID          State        Country
# 0            Abercrombie & Fitch    60914      New York   United States
# 1               Aeropostale Inc.  2612145      New York   United States
# 2               Amazon.com, Inc.    11708    Washington   United States
# 3      American Eagle Outfitters   862441  Pennsylvania   United States
# 4                  Anthropologie  5455028  Pennsylvania   United States
# ..                           ...      ...            ...            ...
# 244              Warehouse Group   130172            NaN    New Zealand
# 245  Woolworths Holdings Limited    56864            NaN   South Africa
# 246                   Zalando SE  2608717            NaN        Germany
# 247                         Zara    18215            NaN          Spain
# 248                       Zeeman  3096058            NaN    Netherlands
#
# [249 rows x 4 columns]

# %%
combined_df = pd.merge(company_cleaned_df,cleaned_df, on="Company", how='inner')
combined_df
# Out:
#                  Company       ID      State        Country  Year     Value  \
# 0    Abercrombie & Fitch    60914  New York   United States  2021  0.000000
# 1    Abercrombie & Fitch    60914  New York   United States  2021  1.818182
# 2    Abercrombie & Fitch    60914  New York   United States  2021  4.444444
# 3    Abercrombie & Fitch    60914  New York   United States  2021  1.111111
# 4       Aeropostale Inc.  2612145  New York   United States  2021  0.000000
# ..                   ...      ...        ...            ...   ...       ...
# 947                 Zara    18215        NaN          Spain  2021  1.111111
# 948               Zeeman  3096058        NaN    Netherlands  2021  1.428571
# 949               Zeeman  3096058        NaN    Netherlands  2021  0.000000
# 950               Zeeman  3096058        NaN    Netherlands  2021  4.444444
# 951               Zeeman  3096058        NaN    Netherlands  2021  6.666667
#
#                                                 Metric
# 0    Decarbonisation, Deforestation and Regeneratio...
# 1             5.4 Overconsumption, Waste & Circularity
# 2                 5.3 Sustainable Sourcing & Materials
# 3                   Towards Paying Living Wages Score
# 4    Decarbonisation, Deforestation and Regeneratio...
# ..                                                 ...
# 947                 Towards Paying Living Wages Score
# 948  Decarbonisation, Deforestation and Regeneratio...
# 949           5.4 Overconsumption, Waste & Circularity
# 950               5.3 Sustainable Sourcing & Materials
# 951                 Towards Paying Living Wages Score
#
# [952 rows x 7 columns]

# %%
#checking on whether the number of rows match in the final dataset
len(cleaned_df)
cleaned_df["Company"].nunique()
combined_df["Company"].nunique()
company_cleaned_df["Company"].nunique()
list(company_cleaned_df["Company"])

# %%
list(cleaned_df["Company"].unique())

# %%
cleaned_df[cleaned_df['Company'].str.contains('"')]

# %%
list(cleaned_df["Company"].unique())

# %%
list(company_cleaned_df["Company"].unique())

# %%
company_cleaned_df[company_cleaned_df["Company"]=="Ontario"]

# %%
company_df[company_df["Name"]=="Ontario"]
